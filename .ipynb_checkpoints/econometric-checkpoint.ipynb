# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
from fredapi import Fred
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.ar_model import AutoReg

# %% [markdown]
# https://towardsdatascience.com/how-to-use-an-autoregressive-ar-model-for-time-series-analysis-bb12b7831024

# %%
FRED_API_KEY = "29b81578246f3b1d8661dfdb956124ba"
fred = Fred(api_key=FRED_API_KEY)

# %% [markdown]
# Get time series data

# %%
df = fred.get_series('VIXCLS')
df = pd.DataFrame(df, columns=['VIX'])
df.index = pd.to_datetime(df.index, format='%Y-%m-%D')
df = df[df['VIX'].notna()]

# %%
fig, ax = plt.subplots(figsize=(26,8))
plot_acf(df['VIX'], lags=100, ax=ax)
plt.ylim([0,1])
plt.yticks(np.arange(0.1, 1.1, 0.1))
plt.xticks(np.arange(1, 101, 1), rotation=90)
plt.axhline(y=0.5, color="green")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(26,8))
plot_pacf(df['VIX'], lags=10, ax=ax)
plt.ylim([0,1])
plt.yticks(np.arange(0.1, 1.1, 0.1))
plt.xticks(np.arange(1, 11, 1), rotation=90)
plt.axhline(y=0.5, color="green")
plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorrun/lib/python3.8/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
test_size = 100

df_train = df['VIX'].iloc[:-test_size]
df_test = df['VIX'].iloc[-test_size:]

# %%
model = AutoReg(df_train, lags=30).fit()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorrun/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
