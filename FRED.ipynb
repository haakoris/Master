# %%
import numpy as np
import pandas as pd
from fredapi import Fred
from matplotlib import pyplot as plt

# %%
FRED_API_KEY = "29b81578246f3b1d8661dfdb956124ba"
fred = Fred(api_key=FRED_API_KEY)
frames_vix_dataset = []

# %%
VIX = fred.get_series('VIXCLS')
VIX = pd.DataFrame(VIX, columns=['VIX'])
VIX.index = pd.to_datetime(VIX.index, format='%Y-%m-%D')
frames_vix_dataset.append(VIX)
VIX = VIX.ffill()
VIX.head()
# Out:
#               VIX
# 1990-01-02  17.24
# 1990-01-03  18.19
# 1990-01-04  19.22
# 1990-01-05  20.11
# 1990-01-08  20.26

# %%
OVX = fred.get_series('OVXCLS')
OVX = pd.DataFrame(OVX, columns=['OVX'])
OVX.index = pd.to_datetime(OVX.index, format='%Y-%m-%D')
OVX.head()
# Out:
#               OVX
# 2007-05-10  27.09
# 2007-05-11  26.41
# 2007-05-14  27.23
# 2007-05-15  27.89
# 2007-05-16  27.07

# %% [markdown]
# Economic Policy Uncertainty Index for United States (USEPUINDXD)

# %%
US_EPU = fred.get_series('USEPUINDXD', observation_start='1990-01-02')
US_EPU = pd.DataFrame(US_EPU, columns=['US_EPU'])
US_EPU.index = pd.to_datetime(US_EPU.index, format='%Y-%m-%D')
frames_vix_dataset.append(US_EPU)
US_EPU.head()
# Out:
#             US_EPU
# 1990-01-02  169.23
# 1990-01-03   59.10
# 1990-01-04   76.38
# 1990-01-05   57.82
# 1990-01-06  218.48

# %% [markdown]
# Federal Funds Effective Rate (DFF)

# %%
DFF = fred.get_series('DFF', observation_start='1990-01-02')
DFF = pd.DataFrame(DFF, columns=['DFF'])
DFF.index = pd.to_datetime(DFF.index, format='%Y-%m-%D')
frames_vix_dataset.append(DFF)
DFF.head()
# Out:
#              DFF
# 1990-01-02  8.54
# 1990-01-03  8.37
# 1990-01-04  8.29
# 1990-01-05  8.20
# 1990-01-06  8.20

# %% [markdown]
# Bank Prime Loan Rate

# %%
DPRIME = fred.get_series('DPRIME', observation_start='1990-01-02')
DPRIME = pd.DataFrame(DPRIME, columns = ['DPRIME'])
DPRIME.index = pd.to_datetime(DPRIME.index, format='%Y-%m-%D')
frames_vix_dataset.append(DPRIME)
DPRIME.head()
# Out:
#             DPRIME
# 1990-01-02    10.5
# 1990-01-03    10.5
# 1990-01-04    10.5
# 1990-01-05    10.5
# 1990-01-08    10.0

# %% [markdown]
# Moody's Seasoned Aaa Corporate Bond Yield

# %%
DAAA = fred.get_series('DAAA', observation_start='1990-01-02')
DAAA = pd.DataFrame(DAAA, columns = ['DAAA'])
DAAA.index = pd.to_datetime(DAAA.index, format='%Y-%m-%D')
frames_vix_dataset.append(DAAA)
DAAA.head()
# Out:
#             DAAA
# 1990-01-02  8.87
# 1990-01-03  8.90
# 1990-01-04  8.89
# 1990-01-05  8.88
# 1990-01-08  8.90

# %% [markdown]
# Moody's Seasoned Baa Corporate Bond Yield Daily

# %%
DBAA = fred.get_series('DBAA', observation_start='1990-01-02')
DBAA = pd.DataFrame(DBAA, columns = ['DBAA'])
DBAA.index = pd.to_datetime(DBAA.index, format='%Y-%m-%D')
frames_vix_dataset.append(DBAA)
DBAA.head()
# Out:
#             DBAA
# 1990-01-02  9.85
# 1990-01-03  9.86
# 1990-01-04  9.84
# 1990-01-05  9.88
# 1990-01-08  9.88

# %% [markdown]
# 10-Year Treasury Constant Maturity Minus 3-Month Treasury Constant Maturity

# %%
T10Y3M = fred.get_series('T10Y3M', observation_start='1990-01-02')
T10Y3M = pd.DataFrame(T10Y3M, columns = ['T10Y3M'])
T10Y3M.index = pd.to_datetime(T10Y3M.index, format='%Y-%m-%D')
frames_vix_dataset.append(T10Y3M)
T10Y3M.head()
# Out:
#             T10Y3M
# 1990-01-02    0.11
# 1990-01-03    0.10
# 1990-01-04    0.14
# 1990-01-05    0.20
# 1990-01-08    0.23

# %% [markdown]
# Monthly unemployment rate (UNRATE)

# %%
UNRATE = fred.get_series('UNRATE', observation_start='1990-01-02')
UNRATE = pd.DataFrame(UNRATE, columns=["UNRATE"])
UNRATE.index = pd.to_datetime(UNRATE.index, format='%Y-%m-%D')
start_date = UNRATE.index.min() - pd.DateOffset(day=1)
end_date = UNRATE.index.max() + pd.DateOffset(day=31)
dates = pd.date_range(start_date, end_date, freq='D')
UNRATE = UNRATE.reindex(dates, method='ffill')
UNRATE = UNRATE.tail(-1)
frames_vix_dataset.append(UNRATE)
UNRATE.head(32)
# Out:
#             UNRATE
# 1990-01-02     5.4
# 1990-01-03     5.4
# 1990-01-04     5.4
# 1990-01-05     5.4
# 1990-01-06     5.4
# 1990-01-07     5.4
# 1990-01-08     5.4
# 1990-01-09     5.4
# 1990-01-10     5.4
# 1990-01-11     5.4
# 1990-01-12     5.4
# 1990-01-13     5.4
# 1990-01-14     5.4
# 1990-01-15     5.4
# 1990-01-16     5.4
# 1990-01-17     5.4
# 1990-01-18     5.4
# 1990-01-19     5.4
# 1990-01-20     5.4
# 1990-01-21     5.4
# 1990-01-22     5.4
# 1990-01-23     5.4
# 1990-01-24     5.4
# 1990-01-25     5.4
# 1990-01-26     5.4
# 1990-01-27     5.4
# 1990-01-28     5.4
# 1990-01-29     5.4
# 1990-01-30     5.4
# 1990-01-31     5.4
# 1990-02-01     5.3
# 1990-02-02     5.3

# %% [markdown]
# Consumer Price Index for All Urban Consumers: All Items in U.S. City Average (CPIAUCSL) Monthly

# %%
CPIAUCSL = fred.get_series('CPIAUCSL', observation_start='1990-01-02')
CPIAUCSL = pd.DataFrame(CPIAUCSL, columns=["CPIAUCSL"])
CPIAUCSL.index = pd.to_datetime(CPIAUCSL.index, format='%Y-%m-%D')
start_date = CPIAUCSL.index.min() - pd.DateOffset(day=1)
end_date = CPIAUCSL.index.max() + pd.DateOffset(day=31)
dates = pd.date_range(start_date, end_date, freq='D')
CPIAUCSL = CPIAUCSL.reindex(dates, method='ffill')
CPIAUCSL = CPIAUCSL.tail(-1)
frames_vix_dataset.append(CPIAUCSL)
CPIAUCSL.head(32)
# Out:
#             CPIAUCSL
# 1990-01-02     127.5
# 1990-01-03     127.5
# 1990-01-04     127.5
# 1990-01-05     127.5
# 1990-01-06     127.5
# 1990-01-07     127.5
# 1990-01-08     127.5
# 1990-01-09     127.5
# 1990-01-10     127.5
# 1990-01-11     127.5
# 1990-01-12     127.5
# 1990-01-13     127.5
# 1990-01-14     127.5
# 1990-01-15     127.5
# 1990-01-16     127.5
# 1990-01-17     127.5
# 1990-01-18     127.5
# 1990-01-19     127.5
# 1990-01-20     127.5
# 1990-01-21     127.5
# 1990-01-22     127.5
# 1990-01-23     127.5
# 1990-01-24     127.5
# 1990-01-25     127.5
# 1990-01-26     127.5
# 1990-01-27     127.5
# 1990-01-28     127.5
# 1990-01-29     127.5
# 1990-01-30     127.5
# 1990-01-31     127.5
# 1990-02-01     128.0
# 1990-02-02     128.0

# %% [markdown]
# Monthly Personal Savings Rate (PSAVERT)

# %%
PSAVERT = fred.get_series('PSAVERT', observation_start='1990-01-02')
PSAVERT = pd.DataFrame(PSAVERT, columns=["PSAVERT"])
PSAVERT.index = pd.to_datetime(PSAVERT.index, format='%Y-%m-%D')
start_date = PSAVERT.index.min() - pd.DateOffset(day=1)
end_date = PSAVERT.index.max() + pd.DateOffset(day=31)
dates = pd.date_range(start_date, end_date, freq='D')
PSAVERT = PSAVERT.reindex(dates, method='ffill')
PSAVERT = PSAVERT.tail(-1)
frames_vix_dataset.append(PSAVERT)
PSAVERT.head(32)
# Out:
#             PSAVERT
# 1990-01-02      8.0
# 1990-01-03      8.0
# 1990-01-04      8.0
# 1990-01-05      8.0
# 1990-01-06      8.0
# 1990-01-07      8.0
# 1990-01-08      8.0
# 1990-01-09      8.0
# 1990-01-10      8.0
# 1990-01-11      8.0
# 1990-01-12      8.0
# 1990-01-13      8.0
# 1990-01-14      8.0
# 1990-01-15      8.0
# 1990-01-16      8.0
# 1990-01-17      8.0
# 1990-01-18      8.0
# 1990-01-19      8.0
# 1990-01-20      8.0
# 1990-01-21      8.0
# 1990-01-22      8.0
# 1990-01-23      8.0
# 1990-01-24      8.0
# 1990-01-25      8.0
# 1990-01-26      8.0
# 1990-01-27      8.0
# 1990-01-28      8.0
# 1990-01-29      8.0
# 1990-01-30      8.0
# 1990-01-31      8.0
# 1990-02-01      8.6
# 1990-02-02      8.6

# %% [markdown]
# WTI Crude Oil Prices (WTI)

# %%
WTI = fred.get_series('DCOILWTICO', observation_start='1990-01-02')
WTI = pd.DataFrame(WTI, columns=['WTI'])
WTI.index = pd.to_datetime(WTI.index, format='%Y-%m-%D')
frames_vix_dataset.append(WTI)
WTI.head()
# Out:
#               WTI
# 1990-01-02  22.88
# 1990-01-03  23.81
# 1990-01-04  23.41
# 1990-01-05  23.07
# 1990-01-08  21.64

# %% [markdown]
# Crude Oil Prices: Brent-Europe (DCOILBRENTEU)

# %%
BRENT_EU = fred.get_series('DCOILBRENTEU', observation_start='1990-01-02')
BRENT_EU = pd.DataFrame(BRENT_EU, columns=['BRENT_EU'])
BRENT_EU.index = pd.to_datetime(BRENT_EU.index, format='%Y-%m-%D')
frames_vix_dataset.append(BRENT_EU)
BRENT_EU.head()
# Out:
#             BRENT_EU
# 1990-01-02     21.20
# 1990-01-03     22.65
# 1990-01-04     22.50
# 1990-01-05     23.13
# 1990-01-08     21.38

# %% [markdown]
# US Dollars to Euro Spot Exchange Rate (DEXUSEU)

# %%
USDEUR = fred.get_series('DEXUSEU')
USDEUR = pd.DataFrame(USDEUR, columns=['USDEUR'])
USDEUR.index = pd.to_datetime(USDEUR.index, format='%Y-%m-%D')
USDEUR.head()
# Out:
#             USDEUR
# 1999-01-04  1.1812
# 1999-01-05  1.1760
# 1999-01-06  1.1636
# 1999-01-07  1.1672
# 1999-01-08  1.1554

# %% [markdown]
# Japanese Yen to U.S. Dollar Spot Exchange Rate (DEXJPUS)

# %%
DEXJPUS = fred.get_series('DEXJPUS', observation_start='1990-01-02')
DEXJPUS = pd.DataFrame(DEXJPUS, columns=['DEXJPUS'])
DEXJPUS.index = pd.to_datetime(DEXJPUS.index, format='%Y-%m-%D')
frames_vix_dataset.append(DEXJPUS)
DEXJPUS.head()
# Out:
#             DEXJPUS
# 1990-01-02   146.25
# 1990-01-03   145.70
# 1990-01-04   143.37
# 1990-01-05   143.82
# 1990-01-08   144.10

# %% [markdown]
# CBOE Gold ETF Volatility Index (GVZCLS)

# %%
GVZCLS = fred.get_series('GVZCLS')
GVZCLS = pd.DataFrame(GVZCLS, columns=['GVZCLS'])
GVZCLS.index = pd.to_datetime(GVZCLS.index, format='%Y-%m-%D')
GVZCLS.head()
# Out:
#             GVZCLS
# 2008-06-03   22.89
# 2008-06-04   22.69
# 2008-06-05   22.78
# 2008-06-06   23.60
# 2008-06-09   24.47

# %% [markdown]
# Dummy variables

# %%
print(len(frames_vix_dataset))
# Out:
# 13

# %%
df = pd.concat(frames_vix_dataset, axis=1)
a = np.arange(len(df))
df['DUMMY'] = a

# %%
nan_count = df.isna().sum()
print(nan_count)
# Out:
# VIX         3768
# US_EPU         1
# DFF            3
# DPRIME      3788
# DAAA        3811
# DBAA        3811
# T10Y3M      3830
# UNRATE        17
# CPIAUCSL      17
# PSAVERT       48
# WTI         3788
# BRENT_EU    3718
# DEXJPUS     3803
# DUMMY          0
# dtype: int64

# %%
df = df.ffill(axis=0)

# %%
nan_count = df.isna().sum()
print(nan_count)
# Out:
# VIX         0
# US_EPU      0
# DFF         0
# DPRIME      0
# DAAA        0
# DBAA        0
# T10Y3M      0
# UNRATE      0
# CPIAUCSL    0
# PSAVERT     0
# WTI         0
# BRENT_EU    0
# DEXJPUS     0
# DUMMY       0
# dtype: int64

# %%
fig, axs = plt.subplots(nrows=14, ncols=1, figsize=(10, 10))

for idx, column in enumerate(df.columns):
    axs[idx].plot(df[column])

# %%
df.to_csv('feature_selection/features.csv')
